# %%
import os
import pandas as pd

# %%
cwd = os.getcwd()

# %%
print(cwd)
# Out:
# D:\github\Johnny_Data606

# %%
amazon_product_data_dir = 'D:\\downloads\\amazon_customer_reviews\\amazon_product_data\\home\\sdf'

# %%
files = os.listdir(amazon_product_data_dir)

# %%
print(files)
# Out:
# ['marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv']

# %%
amazon_data_path = os.path.join(amazon_product_data_dir,files[0])
os.path.exists(amazon_data_path)
# Out:
# True

# %%
product_df = pd.read_csv(amazon_data_path)

# %%
product_df
# Out:
#                                 Uniq Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                             Product Name  Brand Name  Asin  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...         NaN   NaN
# 1      Electronic Snap Circuits Mini Kits Classpack, ...         NaN   NaN
# 2      3Doodler Create Flexy 3D Printing Filament Ref...         NaN   NaN
# 3      Guillow Airplane Design Studio with Travel Cas...         NaN   NaN
# 4                       Woodstock- Collage 500 pc Puzzle         NaN   NaN
# ...

# %%
product_df.iloc[0]
# Out:
# Uniq Id                                   4c69b61db1fc16e7013b43fc926e502d
# Product Name             DB Longboards CoreFlex Crossbow 41" Bamboo Fib...
# Brand Name                                                             NaN
# Asin                                                                   NaN
# Category                 Sports & Outdoors | Outdoor Recreation | Skate...
# Upc Ean Code                                                           NaN
# List Price                                                             NaN
# Selling Price                                                      $237.68
# Quantity                                                               NaN
# Model Number                                                           NaN
# About Product            Make sure this fits by entering your model num...
# Product Specification    Shipping Weight: 10.7 pounds (View shipping ra...
# ...

# %%
product_df['Model Number'].value_counts()
# Out:
# Model Number
# -                            35
# Hovertrax 2.0 Hover Board    11
# F3                            6
# Swagtron T1 Hover Board       4
# I200202701                    4
#                              ..
# NOV178109                     1
# 103596                        1
# 32754                         1
# 3003-IAMWOLF                  1
# ML2.0-4OR                     1
# Name: count, Length: 8109, dtype: int64

# %%
id = 'B001E4KFG0'

# %%
# Using loc to find the row(s)
matching_rows = product_df.loc[product_df['Sku'] == id]

print(matching_rows)
# Out:
# Empty DataFrame
# Columns: [Uniq Id, Product Name, Brand Name, Asin, Category, Upc Ean Code, List Price, Selling Price, Quantity, Model Number, About Product, Product Specification, Technical Details, Shipping Weight, Product Dimensions, Image, Variants, Sku, Product Url, Stock, Product Details, Dimensions, Color, Ingredients, Direction To Use, Is Amazon Seller, Size Quantity Variant, Product Description]
# Index: []
#
# [0 rows x 28 columns]

# %%
import pandas as pd

# Example DataFrame with some NaN values in 'column_name'
data = {
    'column_name': [1, 2, None, 4, 5, None],  # 'None' represents NaN values
    'other_column': ['a', 'b', 'c', 'd', 'e', 'f']
}
df = pd.DataFrame(data)

# Select the 'column_name' and drop NaN values from it
non_nan_column_values = df['column_name'].dropna()

print(non_nan_column_values)
