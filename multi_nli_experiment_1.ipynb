# %%
pip install datasets
# Out:
# ...
#    ---------------------------------------- 0.0/510.5 kB ? eta -:--:--
#    --------- ------------------------------ 122.9/510.5 kB 3.5 MB/s eta 0:00:01
#    ------------------------ --------------- 317.4/510.5 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  501.8/510.5 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 510.5/510.5 kB 4.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.2/24.9 MB 7.6 MB/s eta 0:00:04
#     --------------------------------------- 0.5/24.9 MB 5.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.8/24.9 MB 5.3 MB/s eta 0:00:05
#    - -------------------------------------- 1.0/24.9 MB 5.4 MB/s eta 0:00:05
#    -- ------------------------------------- 1.3/24.9 MB 5.3 MB/s eta 0:00:05
#    -- ------------------------------------- 1.5/24.9 MB 5.3 MB/s eta 0:00:05
# ...

# %%
from datasets import load_dataset

def explore_multi_nli():
    # Load the Multi-NLI dataset
    dataset = load_dataset("multi_nli")
    
    # Print basic information about the dataset
    print("Dataset Structure:", dataset)
    print("Available Splits:", list(dataset.keys()))
    
    # Explore a few examples from the training set
    for i in range(5):
        example = dataset['train'][i]
        print(f"\nExample {i+1}:")
        print("Premise:", example['premise'])
        print("Hypothesis:", example['hypothesis'])
        print("Label:", example['label'])

# Call the function to start exploring
explore_multi_nli()
# Out:
# Dataset Structure: DatasetDict({
#     train: Dataset({
#         features: ['promptID', 'pairID', 'premise', 'premise_binary_parse', 'premise_parse', 'hypothesis', 'hypothesis_binary_parse', 'hypothesis_parse', 'genre', 'label'],
#         num_rows: 392702
#     })
#     validation_matched: Dataset({
#         features: ['promptID', 'pairID', 'premise', 'premise_binary_parse', 'premise_parse', 'hypothesis', 'hypothesis_binary_parse', 'hypothesis_parse', 'genre', 'label'],
#         num_rows: 9815
#     })
#     validation_mismatched: Dataset({
#         features: ['promptID', 'pairID', 'premise', 'premise_binary_parse', 'premise_parse', 'hypothesis', 'hypothesis_binary_parse', 'hypothesis_parse', 'genre', 'label'],
#         num_rows: 9832
#     })
# })
# Available Splits: ['train', 'validation_matched', 'validation_mismatched']
#
# Example 1:
# Premise: Conceptually cream skimming has two basic dimensions - product and geography.
# ...

# %%
#download_dir = 'D:\\downloads'
download_dir = 'D:\\downloads\\amazon_customer_reviews'
print(download_dir)
